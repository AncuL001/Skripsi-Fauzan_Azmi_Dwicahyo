# %%
from ultralytics import YOLO

# %%
downloads_folder = 'downloads'

# %%
model = YOLO(f'{downloads_folder}/yolov8n.pt')

# %%
results = model.predict()
# Out:
# WARNING  'source' is missing. Using 'source=C:\Users\USER\Codes\_university\skripsi\.venv\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\USER\Codes\_university\skripsi\.venv\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 199.2ms
# image 2/2 C:\Users\USER\Codes\_university\skripsi\.venv\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 145.6ms
# Speed: 2.5ms preprocess, 172.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)

# %%
from PIL import Image
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    display(im)
# Out:
# <PIL.Image.Image image mode=RGB size=810x1080>
# <PIL.Image.Image image mode=RGB size=1280x720>
